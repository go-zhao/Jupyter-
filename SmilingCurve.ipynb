# %% [markdown]
# # 我的第一个 Python 程序
# **向新世界问好**

# %%
print('Hello World!')
# Out:
# Hello World!

# %% [markdown]
# # 画出我的微笑曲线

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.arange(-10,10,0.1)
y1=x**2
y2=(x/2)**2+75
plt.plot(x,y1)
plt.plot(x,y2)
